# %% [markdown]
# # FINAL PROJECT
# ### Fiona Callahan, Sofia Verdi

# %% [markdown]
# ## OUR DATA: Healthcare Risk Factor Dataset
# * **"Author"**: AbdalluH ahmed
# * **NOTE:** Does not originate from real patient records
# * Updated every 2 months
# * **Format: CSV file**
#     * Similar to what we have been working with in class
# * Link at bottom in Citations
#
# #### Describes individuals' health conditions
#
# * Full of 30,000 records
# * 20 different features (some will be removed due to noise)
#
# ##### Attributes
# * Most important ones:
#     * Blood pressure (Decimal)
#     * BMI (Body Mass Index: Decimal)
#     * Length of Stay (hospital length of stay (in days))
#     * Family history (binary: 0 (no) OR 1 (yes))
#         * Does not go into much detail
#     * Cholesterol (the level)
#     * Oxygen Saturation
#     * Age, Gender
# * NOTE: Most of our data is numeric, so might have to discretize certain columns
# * OTHERS: (might be noise)
#     * Glucose, hbA1c, Smoking, Alchohol, Stress Level, Sleep Hours, Triglycerides, Diet Score, Physical Activity
#     * two defininitely noisy columns: "random_notes" (a lot of values missing), "noise_col"
#
# * What will we be classifying?
#     * Medical Condition:
#         * EX: Diabetes, Hypertension, Asthma, Obesity
#     * Other options: Blood Pressure, LengthOfStay, Diet Quality Score
#
#
# ##### Anticipated Challenges
# * Noise data, missing values
#     * Will have to decide between keeping these values or using smoothing techniques
# * Feature selection techniques: what can we employ
#     * Some potential options:
#         1. Entropy: to discover what attributes provide the most amount of information gain
#         2. Embedded Approach: Include this process as part of the learning algorithm
#         3. Filter based: Use of stats to see what attributes would be most beneficial to keep
#     * But also, just overall context and knowledge about the realm of health and medicine
#         * Could also research what specifically determines health conditions that we are looking at
# * Picking the correct attributes that gives us the best prediction: since there are so many
#     * Due to what we know about these medical conditions, there should be decent correlation
#
# ##### Potential Impact
# * Why could our results be useful?
#     * In the health science field, nurses perform similar functions as this to decipher what treatment to go forward with
#     * Our results could be useful, as well, in determining if this data set needs to be strengthened or not (EX: deleting some features)
#     * More broadly, medical workers can use this information to help improve classification of medical conditions, thus improving the ability to reconize certain conditions in patients
# * Stakeholders
#     * Medical field community
#     * Owner of this dataset: find out more of its use
#     * The patients that hold these conditions
#         * Can see what causes their health states
#     * Patients that are not in the dataset, and wnat to know why their feeling what they are feeling
#
# ##### CITATIONS
# * Previous work from Gina Sprint 222 class (final project)
# * Kaggle Dataset: https://www.kaggle.com/datasets/abdallaahmed77/healthcare-risk-factors-dataset/data
# * steps on feature selection to improve performance: https://roundtable.datascience.salon/feature-selection-in-machine-learning?gad_source=1&gad_campaignid=22114556059&gbraid=0AAAAA-Q8n0syzjRlpw-PPjskFoihArYAw&gclid=CjwKCAiAoNbIBhB5EiwAZFbYGJUFHzAZKD0uCvPFmfSJYZN_1D-_ulBynxjBVrLZRKleF4v036fLYRoCW1gQAvD_BwE
# * Research about the conditions we are classifying (for confirmation that our classifier is working)
